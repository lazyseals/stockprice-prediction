# %%
import numpy as np
import pandas as pd
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler

# train data for the model
data = ["../data/GE.csv", "../data/AAPL.csv", "../data/DJI.csv", "../data/GSPC.csv"]

# load the model
model = load_model("../models/multiple-layer-lstm-with-dense-with-normalization.h5")

for i in range(0, 4):
    # load the data to evaluate the model
    df = pd.read_csv(data[i])

    # add new column Open_before which contains the open values of the previous day
    df["Open_before"] = df["Open"].shift(1)

    # calculate the procentual change of the open value of the current day to the 
    # open value of the day before
    df["Open_changes"] = (df["Open"] / df["Open_before"]) - 1

    # throw out the first line which has NaN as value because of the previous shift of values 
    df = df.dropna()

    # reset index to start by 0
    df.index -= 1

    changes = df["Open_changes"]
                   
    # normalize data

    # border to split in test and training data
    split_border = int(len(changes) * 0.8)

    # build test and training data
    train = np.array(changes[:split_border]).reshape(-1, 1)
    test = np.array(changes[split_border:]).reshape(-1, 1)

    scaler = MinMaxScaler()

    # train the scaler with training data and smooth data
    smoothing_window_size = 2500
    if len(df["Open"]) > 10000:
        top_range = 10000
    else:
        top_range = 5000

    for di in range(0, top_range, smoothing_window_size):
        scaler.fit(train[di:di+smoothing_window_size,:])
        train[di:di+smoothing_window_size,:] = scaler.transform(train[di:di+smoothing_window_size,:])

    # normalize the rest of the data which is len(train) - 10000
    scaler.fit(train[di+smoothing_window_size:,:])
    train[di+smoothing_window_size:,:] = scaler.transform(train[di+smoothing_window_size:,:])

    # normalize test data
    test = scaler.transform(test)

    # reshape test and train data
    train = train.reshape(-1)
    test = test.reshape(-1)
                   
    # perform exponential moving average
    EMA = 0.0
    gamma = 0.1
    for ti in range(len(train)):
        EMA = gamma * train[ti] + (1 - gamma) * EMA
        train[ti] = EMA
                   
    # TODO: Wie kriege ich aus den normalisierten Daten nun meine X und Y Daten im richtigen Format
    train_len = len(train)
    test_len = len(test)

    Y_train = np.array(train[:train_len-20])
    Y_test = np.array(test[:test_len-20])
    X_train = []
    X_test = []

    # predict price with previous 20 entries
    for i in range(0, len(train) - 20):
        X_train.append(np.array(train[i+1:i+21]))
    for i in range(0, len(test) - 20):
        X_test.append(np.array(test[i+1:i+21]))

    # reshape training data
    X_train = np.array(X_train).reshape(-1, 20, 1)
    X_test = np.array(X_test).reshape(-1, 20, 1)
                   
    model.fit(X_train, Y_train, batch_size=32, epochs=10)
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0908 21:56:56.792549 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0908 21:56:56.822096 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0908 21:56:56.827611 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0908 21:56:58.017500 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0908 21:56:58.017500 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0908 21:56:58.424205 17576 deprecation_wrapper.py:119] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0908 21:56:59.078346 17576 deprecation.py:323] From C:\Users\Daniel\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in get_attr(self, name)
#    2638       with c_api_util.tf_buffer() as buf:
# -> 2639         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2640         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'lstm_1/while/mul_5' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     397     try:
# --> 398       xla_compile = op.get_attr("_XlaCompile")
#     399       xla_separate_compiled_gradients = op.get_attr(
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in get_attr(self, name)
#    2642       # Convert to ValueError for backwards compatibility.
# -> 2643       raise ValueError(str(e))
#    2644     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'lstm_1/while/mul_5' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-190bba09a781> in <module>
#       8
#       9 # load the model
# ---> 10 model = load_model("../models/trained")
#      11
#      12 for i in range(0, 4):
#
# ~\.conda\envs\python36\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     417     f = h5dict(filepath, 'r')
#     418     try:
# --> 419         model = _deserialize_model(f, custom_objects, compile)
#     420     finally:
#     421         if opened_new_file:
#
# ~\.conda\envs\python36\lib\site-packages\keras\engine\saving.py in _deserialize_model(f, custom_objects, compile)
#     315         if 'optimizer_weights' in f:
#     316             # Build train function (to get weight updates).
# --> 317             model._make_train_function()
#     318             optimizer_weights_group = f['optimizer_weights']
#     319             optimizer_weight_names = [
#
# ~\.conda\envs\python36\lib\site-packages\keras\engine\training.py in _make_train_function(self)
#     507                     training_updates = self.optimizer.get_updates(
#     508                         params=self._collected_trainable_weights,
# --> 509                         loss=self.total_loss)
#     510                 updates = (self.updates +
#     511                            training_updates +
#
# ~\.conda\envs\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\.conda\envs\python36\lib\site-packages\keras\optimizers.py in get_updates(self, loss, params)
#     254     @interfaces.legacy_get_updates_support
#     255     def get_updates(self, loss, params):
# --> 256         grads = self.get_gradients(loss, params)
#     257         accumulators = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#     258         self.weights = accumulators
#
# ~\.conda\envs\python36\lib\site-packages\keras\optimizers.py in get_gradients(self, loss, params)
#      87
#      88     def get_gradients(self, loss, params):
# ---> 89         grads = K.gradients(loss, params)
#      90         if None in grads:
#      91             raise ValueError('An operation has `None` for gradient. '
#
# ~\.conda\envs\python36\lib\site-packages\keras\backend\tensorflow_backend.py in gradients(loss, variables)
#    2755         A gradients tensor.
#    2756     """
# -> 2757     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#    2758
#    2759
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     156         ys, xs, grad_ys, name, colocate_gradients_with_ops,
#     157         gate_gradients, aggregation_method, stop_gradients,
# --> 158         unconnected_gradients)
#     159   # pylint: enable=protected-access
#     160
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gradients_util.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     729                 # functions.
#     730                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 731                                          lambda: grad_fn(op, *out_grads))
#     732               else:
#     733                 # For function call ops, we add a 'SymbolicGradient'
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gradients_util.py in _MaybeCompile(scope, op, func, grad_fn)
#     401       xla_scope = op.get_attr("_XlaScope").decode()
#     402     except ValueError:
# --> 403       return grad_fn()  # Exit early
#     404
#     405   if not xla_compile:
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gradients_util.py in <lambda>()
#     729                 # functions.
#     730                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 731                                          lambda: grad_fn(op, *out_grads))
#     732               else:
#     733                 # For function call ops, we add a 'SymbolicGradient'
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\math_grad.py in _MulGrad(op, grad)
#    1042   sx = array_ops.shape(x)
#    1043   sy = array_ops.shape(y)
# -> 1044   rx, ry = gen_array_ops.broadcast_gradient_args(sx, sy)
#    1045   x = math_ops.conj(x)
#    1046   y = math_ops.conj(y)
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in broadcast_gradient_args(s0, s1, name)
#     826   # Add nodes to the TensorFlow graph.
#     827   _, _, _op = _op_def_lib._apply_op_helper(
# --> 828         "BroadcastGradientArgs", s0=s0, s1=s1, name=name)
#     829   _result = _op.outputs[:]
#     830   _inputs_flat = _op.inputs
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3614           input_types=input_types,
#    3615           original_op=self._default_original_op,
# -> 3616           op_def=op_def)
#    3617       self._create_op_helper(ret, compute_device=compute_device)
#    3618     return ret
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2041
#    2042     if not c_op:
# -> 2043       self._control_flow_post_processing()
#    2044
#    2045   def _control_flow_post_processing(self):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in _control_flow_post_processing(self)
#    2052       control_flow_util.CheckInputFromValidContext(self, input_tensor.op)
#    2053     if self._control_flow_context is not None:
# -> 2054       self._control_flow_context.AddOp(self)
#    2055
#    2056   def _reconstruct_sequence_inputs(self, op_def, inputs, attrs):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in AddOp(self, op)
#    2481             op_input_ctxt._AddOpInternal(op)
#    2482             return
# -> 2483     self._AddOpInternal(op)
#    2484
#    2485   def _AddOpInternal(self, op):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _AddOpInternal(self, op)
#    2502       for index in range(len(op.inputs)):
#    2503         x = op.inputs[index]
# -> 2504         real_x = self.AddValue(x)
#    2505         if real_x != x:
#    2506           op._update_input(index, real_x)  # pylint: disable=protected-access
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in AddValue(self, val)
#    2429               forward_ctxt = forward_ctxt.GetWhileContext()
#    2430           if forward_ctxt == grad_ctxt.grad_state.forward_context:
# -> 2431             real_val = grad_ctxt.grad_state.GetRealValue(val)
#    2432             self._external_values[val.name] = real_val
#    2433             return real_val
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in GetRealValue(self, value)
#    1024           # Record the history of this value in forward_ctxt.
#    1025           self._grad_context.Exit()
# -> 1026           history_value = cur_grad_state.AddForwardAccumulator(cur_value)
#    1027           self._grad_context.Enter()
#    1028           break
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in AddForwardAccumulator(self, value, dead_branch)
#     905           self.forward_context.Enter()
#     906           push = gen_data_flow_ops.stack_push_v2(
# --> 907               enter_acc, value, swap_memory=swap_enabled)
#     908           self.forward_context.Exit()
#     909           # Protect stack push and order it before forward_index.
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\gen_data_flow_ops.py in stack_push_v2(handle, elem, swap_memory, name)
#    5525   _, _, _op = _op_def_lib._apply_op_helper(
#    5526         "StackPushV2", handle=handle, elem=elem, swap_memory=swap_memory,
# -> 5527                        name=name)
#    5528   _result = _op.outputs[:]
#    5529   _inputs_flat = _op.inputs
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, dtypes=None, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3614           input_types=input_types,
#    3615           original_op=self._default_original_op,
# -> 3616           op_def=op_def)
#    3617       self._create_op_helper(ret, compute_device=compute_device)
#    3618     return ret
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2041
#    2042     if not c_op:
# -> 2043       self._control_flow_post_processing()
#    2044
#    2045   def _control_flow_post_processing(self):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in _control_flow_post_processing(self)
#    2052       control_flow_util.CheckInputFromValidContext(self, input_tensor.op)
#    2053     if self._control_flow_context is not None:
# -> 2054       self._control_flow_context.AddOp(self)
#    2055
#    2056   def _reconstruct_sequence_inputs(self, op_def, inputs, attrs):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in AddOp(self, op)
#    2481             op_input_ctxt._AddOpInternal(op)
#    2482             return
# -> 2483     self._AddOpInternal(op)
#    2484
#    2485   def _AddOpInternal(self, op):
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _AddOpInternal(self, op)
#    2509       # Add a control dependency to prevent loop invariants from
#    2510       # enabling ops that should not be executed.
# -> 2511       self._MaybeAddControlDependency(op)
#    2512       for x in op.outputs:
#    2513         self._values.add(x.name)
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _MaybeAddControlDependency(self, op)
#    2548       return True
#    2549
# -> 2550     if _IsOpFree(op):
#    2551       # pylint: disable=protected-access
#    2552       op._add_control_input(self.GetControlPivot().op)
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in _IsOpFree(op)
#    2540         return False
#    2541       # pylint: disable=protected-access
# -> 2542       if op.graph._is_function(op.type) or op.type == "SymbolicGradient":
#    2543         return True
#    2544       # pylint: enable=protected-access
#
# ~\.conda\envs\python36\lib\site-packages\tensorflow\python\framework\ops.py in type(self)
#    2513   def type(self):
#    2514     """The type of the op (e.g. `"MatMul"`)."""
# -> 2515     return c_api.TF_OperationOpType(self._c_op)
#    2516
#    2517   @property
#
# KeyboardInterrupt:

# %%
model.save('../models/trained')
