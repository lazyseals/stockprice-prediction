# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
import os

# choose a local (colab) directory to store the data.
local_root_path = os.path.expanduser("~/data")
try:
  os.makedirs(local_root_path)
except: pass

def ListFolder(google_drive_id, destination):
  file_list = drive.ListFile({'q': "'%s' in parents and trashed=false" % google_drive_id}).GetList()
  counter = 0
  for f in file_list:
    # If it is a directory then, create the dicrectory and upload the file inside it
    if f['mimeType']=='application/vnd.google-apps.folder': 
      folder_path = os.path.join(destination, f['title'])
      os.makedirs(folder_path)
      print('creating directory {}'.format(folder_path))
      ListFolder(f['id'], folder_path)
    else:
      fname = os.path.join(destination, f['title'])
      f_ = drive.CreateFile({'id': f['id']})
      f_.GetContentFile(fname)
      counter += 1
  print('{} files were uploaded in {}'.format(counter, destination))

ListFolder("1A2XBt4MTMmEmgMCmKEuJQCh1HaJGmkSa", local_root_path)
# Out:
# 2 files were uploaded in /root/data

# %%
from requests import get
import json
import re 
from textblob import TextBlob
import datetime
import numpy as np
import pandas as pd

# %%
# perform request
def perform_request(year, month):
    api_key = 's6J10zzMfa9Vm5q1AufUu4gTovcVJEmo'
    req = 'https://api.nytimes.com/svc/archive/v1/{}/{}.json?api-key={}'
    req = req.format(str(year), str(month), api_key)
    # return response
    return get(req)

# %%
# match keywords with article id
def match_id_to_keyword(response):
    id_to_keyword = {}
    keywords = []
    for article in response.json()["response"]["docs"]:
        id = article["_id"]
        for keyword_data in article["keywords"]:
            keywords.append(keyword_data["value"].lower())
        id_to_keyword[id] = keywords
        keywords = []
    return id_to_keyword

# %%
# find articles which contain keyword
def get_article_id(queue, id_to_keyword):
    id_with_keyword = []
    for id, keywords in id_to_keyword.items():
        for keyword in keywords:
            if str(queue) in keyword:
                id_with_keyword.append(id)
    return id_with_keyword

# %%
# get article information for article_id
def get_article_information_for_queue(queue, response, id_to_keyword):
    ids = get_article_id(str(queue), id_to_keyword)
    id_to_date = {}
    id_to_snippet = {}
    id_to_headline = {}
    for article in response.json()["response"]["docs"]:
        for id in ids:
            if str(id) == str(article["_id"]):
                id_to_date[id] = article["pub_date"]
                id_to_snippet[id] = article["snippet"]
                id_to_headline[id] = article["headline"]["main"]
                break
    return (id_to_date, id_to_snippet, id_to_headline)

# %%
def clean_text(text):
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text).split())

# %%
def get_sentiment(text):
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(clean_text(text)) 
    # set sentiment 
    return analysis.sentiment.polarity

# %%
# perform sentiment analysis for headline snippets
def get_sentiments(id_to_snippet):
    id_to_sentiment = {}
    for id, snippet in id_to_snippet.items():
        id_to_sentiment[id] = get_sentiment(snippet)
    return id_to_sentiment

# %%
import time
from tqdm import tqdm

year = 1980
month = 11
# For each row add sentiment
df = pd.read_csv("/root/data/DJI.csv")
# initial sentiment to 0
for index, row in df.iterrows():
    df.at[index, 'Sentiment'] = 0
    
# add sentiment to dates where news exist
for index, row in df.iterrows():
    try:
        year_df = int(row['Date'][:4])
        month_df = int(row['Date'][5:7])
        day_df = int(row['Date'][8:10])

        # only perform request when params changed
        if year_df > year or month_df > month:
            year = year_df
            month = month_df
            response = perform_request(year, month)
            id_to_keyword = match_id_to_keyword(response)
            (id_to_date, id_to_snippet, id_to_headline) = get_article_information_for_queue(
                "dow jones", response, id_to_keyword)
            id_to_sentiment = get_sentiments(id_to_snippet)
            print('did request')
            print("iteration year: " + str(year) + " month: " + str(month))

        # add sentiment to df when news exist
        for id, date in id_to_date.items():
            if day_df == int(date[8:10]):
                df.at[index, 'Sentiment'] = id_to_sentiment[id]
                print("sentiment changed")
    
    # catching error which occurs due to too many requests
    except KeyError:

        try:
          # wait 1 minute to do the request again due to request limit of api
          time.sleep(60)

          # do the request again after 1 minute
          # no checking for year required because error only occurs when request happens
          response = perform_request(year, month)
          print(response)
          id_to_keyword = match_id_to_keyword(response)
          (id_to_date, id_to_snippet, id_to_headline) = get_article_information_for_queue(
              "dow jones", response, id_to_keyword)
          id_to_sentiment = get_sentiments(id_to_snippet)
          print('did request')
          print("iteration year: " + str(year) + " month: " + str(month))

          # add sentiment to df when news exist
          for id, date in id_to_date.items():
              if day_df == int(date[8:10]):
                  df.at[index, 'Sentiment'] = id_to_sentiment[id]
                  print("sentiment changed")

        # catch all other errors which occur inside the KeyError
        except:
            pass

    # catch all other errors
    except:
        pass
# Out:
# <Response [200]>
# did request
# iteration year: 1985 month: 1
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1985 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1985 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1986 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1986 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1986 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1987 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1987 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1987 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1988 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1988 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1989 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1989 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1989 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1990 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# did request
# iteration year: 1990 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1990 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1991 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1991 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1991 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1991 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 5
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 8
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1992 month: 9
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1992 month: 11
# did request
# iteration year: 1992 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1993 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1993 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1993 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1993 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1994 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1994 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1994 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1995 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1995 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# <Response [429]>
# <Response [429]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1995 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1995 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# did request
# iteration year: 1996 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1996 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [429]>
# <Response [200]>
# did request
# iteration year: 1996 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1996 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 8
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 9
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1996 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1997 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1997 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1997 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 1998 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 1998 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# ...
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 3
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 4
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 5
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2012 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 7
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 8
# sentiment changed
# did request
# iteration year: 2012 month: 9
# did request
# iteration year: 2012 month: 10
# sentiment changed
# sentiment changed
# did request
# iteration year: 2012 month: 11
# <Response [200]>
# did request
# iteration year: 2012 month: 12
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 1
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 2
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 4
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 5
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2013 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 7
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 9
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 10
# sentiment changed
# did request
# iteration year: 2013 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2013 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2014 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2014 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2014 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 1
# did request
# iteration year: 2015 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2015 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2015 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2015 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2016 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 3
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 4
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 5
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 6
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 7
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2016 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 9
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 10
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 11
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2016 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2017 month: 1
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2017 month: 2
# did request
# iteration year: 2017 month: 3
# sentiment changed
# did request
# iteration year: 2017 month: 4
# sentiment changed
# did request
# iteration year: 2017 month: 5
# sentiment changed
# did request
# iteration year: 2017 month: 6
# did request
# iteration year: 2017 month: 7
# did request
# iteration year: 2017 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2017 month: 9
# sentiment changed
# did request
# iteration year: 2017 month: 10
# sentiment changed
# sentiment changed
# did request
# iteration year: 2017 month: 11
# did request
# iteration year: 2017 month: 12
# did request
# iteration year: 2018 month: 1
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2018 month: 2
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2018 month: 3
# did request
# iteration year: 2018 month: 4
# sentiment changed
# did request
# iteration year: 2018 month: 5
# did request
# iteration year: 2018 month: 6
# sentiment changed
# did request
# iteration year: 2018 month: 7
# <Response [200]>
# did request
# iteration year: 2018 month: 8
# did request
# iteration year: 2018 month: 9
# sentiment changed
# did request
# iteration year: 2018 month: 10
# did request
# iteration year: 2018 month: 11
# sentiment changed
# did request
# iteration year: 2018 month: 12
# sentiment changed
# sentiment changed
# sentiment changed
# <Response [200]>
# did request
# iteration year: 2019 month: 1
# sentiment changed
# did request
# iteration year: 2019 month: 2
# did request
# iteration year: 2019 month: 3
# sentiment changed
# did request
# iteration year: 2019 month: 4
# did request
# iteration year: 2019 month: 5
# <Response [200]>
# did request
# iteration year: 2019 month: 6
# did request
# iteration year: 2019 month: 7
# sentiment changed
# sentiment changed
# did request
# iteration year: 2019 month: 8
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# sentiment changed
# did request
# iteration year: 2019 month: 9

# %%
df.to_csv('./dow_jones_sentiments.csv')
